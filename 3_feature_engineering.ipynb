# %%
import pandas as pd 
import numpy as np

pd.__version__
# Out:
# '2.0.0'

# %%
INPUT_DATA = 'data/4_final_dataset/hourly_weather_events_data.csv'
OUTPUT_DATA = 'data/4_final_dataset/final_dataset.csv'

# %%
df_merged = pd.read_csv(INPUT_DATA, delimiter=';')
df_merged.shape
# Out:
# (195085, 59)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_merged[10000:10060]
# Out:
#          city_resolvedAddress day_datetime  day_datetimeEpoch  day_tempmax
# 10000  Кропивницький, Україна   2022-05-10         1652130000         17.7  \
# 10001  Кропивницький, Україна   2022-05-10         1652130000         17.7
# 10002  Кропивницький, Україна   2022-05-10         1652130000         17.7
# 10003  Кропивницький, Україна   2022-05-10         1652130000         17.7
# 10004  Кропивницький, Україна   2022-05-10         1652130000         17.7
# 10005  Кропивницький, Україна   2022-05-10         1652130000         17.7
# 10006  Кропивницький, Україна   2022-05-10         1652130000         17.7
# 10007  Кропивницький, Україна   2022-05-10         1652130000         17.7
# 10008  Кропивницький, Україна   2022-05-10         1652130000         17.7
# 10009  Кропивницький, Україна   2022-05-10         1652130000         17.7
# 10010  Кропивницький, Україна   2022-05-10         1652130000         17.7
# ...

# %% [markdown]
# ### `is_alarm`
# - a boolean value showcasing whether there is an alarm going off in the given region at given time

# %%
df_merged['is_alarm'] = df_merged['event_start_hour'].apply(lambda x: x == x)

# %%
df_merged.head(10)
# Out:
#             city_resolvedAddress day_datetime  day_datetimeEpoch  day_tempmax
# 0  Луцьк, Луцький район, Україна   2022-02-24         1645653600          4.9  \
# 1  Луцьк, Луцький район, Україна   2022-02-24         1645653600          4.9
# 2  Луцьк, Луцький район, Україна   2022-02-24         1645653600          4.9
# 3  Луцьк, Луцький район, Україна   2022-02-24         1645653600          4.9
# 4  Луцьк, Луцький район, Україна   2022-02-24         1645653600          4.9
# 5  Луцьк, Луцький район, Україна   2022-02-24         1645653600          4.9
# 6  Луцьк, Луцький район, Україна   2022-02-24         1645653600          4.9
# 7  Луцьк, Луцький район, Україна   2022-02-24         1645653600          4.9
# 8  Луцьк, Луцький район, Україна   2022-02-24         1645653600          4.9
# 9  Луцьк, Луцький район, Україна   2022-02-24         1645653600          4.9
#
#    day_tempmin  day_temp  day_dew  day_humidity  day_precip  day_precipcover
# ...

# %% [markdown]
# ### `alarms_countrywide`
# - the number of regions where the alarm is on at the moment

# %%
df_merged_v2 = df_merged.copy()
regions_w_alarm_on = df_merged_v2[df_merged_v2['is_alarm']==True].groupby(['day_datetime', 'hour_datetime'])['region'].count()

# %%
regions_feature = pd.DataFrame(regions_w_alarm_on)
regions_feature.head(15)
# Out:
#                             region
# day_datetime hour_datetime
# 2022-02-25   22:00:00            1
#              23:00:00            1
# 2022-02-26   00:00:00            1
#              06:00:00            1
#              07:00:00            2
#              08:00:00            4
#              09:00:00            2
#              10:00:00            3
#              11:00:00            2
#              12:00:00            1
#              13:00:00            1
#              14:00:00            1
#              15:00:00            2
#              16:00:00            4
#              17:00:00            5

# %%
regions_feature = regions_feature.rename(columns={'region': 'alarms_countrywide'})
df_merged_v2 = df_merged_v2.merge(regions_feature, how='left', on=['day_datetime', 'hour_datetime'], )
df_merged_v2.shape
# Out:
# (195085, 61)

# %%
# manually checking the correctness of the feature
df_merged_v2[df_merged_v2['day_datetime']=='2022-02-26'][df_merged_v2['hour_datetime']=='17:00:00']
# Out:
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11392\2923184435.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_merged_v2[df_merged_v2['day_datetime']=='2022-02-26'][df_merged_v2['hour_datetime']=='17:00:00']
#                         city_resolvedAddress day_datetime  day_datetimeEpoch
# 65             Луцьк, Луцький район, Україна   2022-02-26         1645826400  \
# 8115                  Кропивницький, Україна   2022-02-26         1645826400
# 16708                        Дніпро, Україна   2022-02-26         1645826400
# 25931                          Київ, Україна   2022-02-26         1645826400
# 36858                        Херсон, Україна   2022-02-26         1645826400
# 44922                      Чернівці, Україна   2022-02-26         1645826400
# 52907                      Чернігів, Україна   2022-02-26         1645826400
# 61288                         Одеса, Україна   2022-02-26         1645826400
# ...

# %%
#replacing NaN's with 0's
df_merged_v2['alarms_countrywide'] = df_merged_v2['alarms_countrywide'].apply(lambda x: int(x) if x == x else 0)

# %%
df_merged_v2['alarms_countrywide'].describe()
# Out:
# count    195085.000000
# mean          7.232396
# std           9.807864
# min           0.000000
# 25%           1.000000
# 50%           3.000000
# 75%          10.000000
# max          76.000000
# Name: alarms_countrywide, dtype: float64

# %% [markdown]
# ### `n_alarms_last24hrs`
# - the number of alarms in the given region during the last 24 hrs

# %%
df_merged_v3 = df_merged_v2.copy()
# df_merged_v3.dtypes
df_merged_v3.shape
# Out:
# (195085, 61)

# %%
df_merged_v3['datetime'] = pd.to_datetime(
    df_merged_v3['day_datetime'].str.cat(
        df_merged_v3['hour_datetime'], 
        sep=' '))

# %%
df_merged_v3.head(5)
# Out:
#             city_resolvedAddress day_datetime  day_datetimeEpoch  day_tempmax
# 0  Луцьк, Луцький район, Україна   2022-02-24         1645653600          4.9  \
# 1  Луцьк, Луцький район, Україна   2022-02-24         1645653600          4.9
# 2  Луцьк, Луцький район, Україна   2022-02-24         1645653600          4.9
# 3  Луцьк, Луцький район, Україна   2022-02-24         1645653600          4.9
# 4  Луцьк, Луцький район, Україна   2022-02-24         1645653600          4.9
#
#    day_tempmin  day_temp  day_dew  day_humidity  day_precip  day_precipcover
# 0          0.7       2.6      0.0          83.7       0.118             4.17  \
# 1          0.7       2.6      0.0          83.7       0.118             4.17
# 2          0.7       2.6      0.0          83.7       0.118             4.17
# 3          0.7       2.6      0.0          83.7       0.118             4.17
# 4          0.7       2.6      0.0          83.7       0.118             4.17
#
# ...

# %%
df_alarms = df_merged_v3[['region', 'datetime', 'event_start_time']]
df_alarms['dup'] = df_alarms.duplicated(subset=['region', 'event_start_time'], keep='first')
df_alarms.head(100)
# Out:
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11392\1446884810.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_alarms['dup'] = df_alarms.duplicated(subset=['region', 'event_start_time'], keep='first')
#        region            datetime     event_start_time    dup
# 0   Волинська 2022-02-24 00:00:00                  NaN  False
# 1   Волинська 2022-02-24 01:00:00                  NaN   True
# 2   Волинська 2022-02-24 02:00:00                  NaN   True
# 3   Волинська 2022-02-24 03:00:00                  NaN   True
# 4   Волинська 2022-02-24 04:00:00                  NaN   True
# 5   Волинська 2022-02-24 05:00:00                  NaN   True
# 6   Волинська 2022-02-24 06:00:00                  NaN   True
# ...

# %%
df_alarms['dup'] = df_alarms.apply(
    lambda row: not pd.isna(row['event_start_time']) if pd.isna(row['event_start_time']) else row['dup'], axis=1)
# Out:
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11392\1968258992.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_alarms['dup'] = df_alarms.apply(

# %%
df_alarms.head(100)
# Out:
#        region            datetime     event_start_time    dup
# 0   Волинська 2022-02-24 00:00:00                  NaN  False
# 1   Волинська 2022-02-24 01:00:00                  NaN  False
# 2   Волинська 2022-02-24 02:00:00                  NaN  False
# 3   Волинська 2022-02-24 03:00:00                  NaN  False
# 4   Волинська 2022-02-24 04:00:00                  NaN  False
# 5   Волинська 2022-02-24 05:00:00                  NaN  False
# 6   Волинська 2022-02-24 06:00:00                  NaN  False
# 7   Волинська 2022-02-24 07:00:00                  NaN  False
# 8   Волинська 2022-02-24 08:00:00                  NaN  False
# 9   Волинська 2022-02-24 09:00:00                  NaN  False
# 10  Волинська 2022-02-24 10:00:00                  NaN  False
# 11  Волинська 2022-02-24 11:00:00                  NaN  False
# 12  Волинська 2022-02-24 12:00:00                  NaN  False
# 13  Волинська 2022-02-24 13:00:00                  NaN  False
# ...

# %%
df_alarms['event_start_time'] = df_alarms.apply(
    lambda row: np.nan if row['dup'] else row['event_start_time'], axis=1)
# Out:
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11392\1396865283.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_alarms['event_start_time'] = df_alarms.apply(

# %%
df_alarms.head(100)
# Out:
#        region            datetime     event_start_time    dup
# 0   Волинська 2022-02-24 00:00:00                  NaN  False
# 1   Волинська 2022-02-24 01:00:00                  NaN  False
# 2   Волинська 2022-02-24 02:00:00                  NaN  False
# 3   Волинська 2022-02-24 03:00:00                  NaN  False
# 4   Волинська 2022-02-24 04:00:00                  NaN  False
# 5   Волинська 2022-02-24 05:00:00                  NaN  False
# 6   Волинська 2022-02-24 06:00:00                  NaN  False
# 7   Волинська 2022-02-24 07:00:00                  NaN  False
# 8   Волинська 2022-02-24 08:00:00                  NaN  False
# 9   Волинська 2022-02-24 09:00:00                  NaN  False
# 10  Волинська 2022-02-24 10:00:00                  NaN  False
# 11  Волинська 2022-02-24 11:00:00                  NaN  False
# 12  Волинська 2022-02-24 12:00:00                  NaN  False
# 13  Волинська 2022-02-24 13:00:00                  NaN  False
# ...

# %%
df_alarms_v1 = df_alarms.groupby('region')[['datetime', 'event_start_time']].rolling('24H', on='datetime').count()
df_alarms_v1 = pd.DataFrame(df_alarms_v1).reset_index()
df_alarms_v1 = df_alarms_v1.drop('level_1', axis=1)
df_alarms_v1 = df_alarms_v1.rename(columns={'event_start_time':'n_alarms_last24hrs'})
df_alarms_v1.head(200)
# Out:
#                 region            datetime  n_alarms_last24hrs
# 0    Івано-Франківська 2022-02-24 00:00:00                 0.0
# 1    Івано-Франківська 2022-02-24 01:00:00                 0.0
# 2    Івано-Франківська 2022-02-24 02:00:00                 0.0
# 3    Івано-Франківська 2022-02-24 03:00:00                 0.0
# 4    Івано-Франківська 2022-02-24 04:00:00                 0.0
# 5    Івано-Франківська 2022-02-24 05:00:00                 0.0
# 6    Івано-Франківська 2022-02-24 06:00:00                 0.0
# 7    Івано-Франківська 2022-02-24 07:00:00                 0.0
# 8    Івано-Франківська 2022-02-24 08:00:00                 0.0
# 9    Івано-Франківська 2022-02-24 09:00:00                 0.0
# 10   Івано-Франківська 2022-02-24 10:00:00                 0.0
# 11   Івано-Франківська 2022-02-24 11:00:00                 0.0
# 12   Івано-Франківська 2022-02-24 12:00:00                 0.0
# 13   Івано-Франківська 2022-02-24 13:00:00                 0.0
# ...

# %%
df_alarms_v1.shape
# Out:
# (195085, 3)

# %%
df_merged_v4 = pd.merge(df_merged_v3,
    df_alarms_v1, 
    on=['region', 'datetime'])
df_merged_v4.tail(300)
# Out:
#        city_resolvedAddress day_datetime  day_datetimeEpoch  day_tempmax
# 237901     Вінниця, Україна   2023-01-08         1673128800         -2.8  \
# 237902     Вінниця, Україна   2023-01-08         1673128800         -2.8
# 237903     Вінниця, Україна   2023-01-08         1673128800         -2.8
# 237904     Вінниця, Україна   2023-01-08         1673128800         -2.8
# 237905     Вінниця, Україна   2023-01-08         1673128800         -2.8
# 237906     Вінниця, Україна   2023-01-08         1673128800         -2.8
# 237907     Вінниця, Україна   2023-01-08         1673128800         -2.8
# 237908     Вінниця, Україна   2023-01-08         1673128800         -2.8
# 237909     Вінниця, Україна   2023-01-08         1673128800         -2.8
# 237910     Вінниця, Україна   2023-01-08         1673128800         -2.8
# 237911     Вінниця, Україна   2023-01-08         1673128800         -2.8
# 237912     Вінниця, Україна   2023-01-08         1673128800         -2.8
# ...

# %%
df_merged_v4['n_alarms_last24hrs'].isna().sum()
# Out:
# 0

# %%
df_merged_v4.shape
# Out:
# (213199, 63)

# %%
df_merged_v4 = df_merged_v4.drop_duplicates()

# %%
df_merged_v4['n_alarms_last24hrs'] = df_merged_v4['n_alarms_last24hrs'].apply(lambda x: int(x))

# %%
df_merged_v4.tail(100)
# Out:
#        city_resolvedAddress day_datetime  day_datetimeEpoch  day_tempmax
# 238101     Вінниця, Україна   2023-01-16         1673820000          3.7  \
# 238102     Вінниця, Україна   2023-01-16         1673820000          3.7
# 238103     Вінниця, Україна   2023-01-16         1673820000          3.7
# 238104     Вінниця, Україна   2023-01-16         1673820000          3.7
# 238105     Вінниця, Україна   2023-01-17         1673906400          7.1
# 238106     Вінниця, Україна   2023-01-17         1673906400          7.1
# 238107     Вінниця, Україна   2023-01-17         1673906400          7.1
# 238108     Вінниця, Україна   2023-01-17         1673906400          7.1
# 238109     Вінниця, Україна   2023-01-17         1673906400          7.1
# 238110     Вінниця, Україна   2023-01-17         1673906400          7.1
# 238111     Вінниця, Україна   2023-01-17         1673906400          7.1
# 238112     Вінниця, Україна   2023-01-17         1673906400          7.1
# ...

# %% [markdown]
# ### `is_weekend`
# - a boolean value showing whether the given day is a weekend

# %%
df_merged_v5 = df_merged_v4.copy()
df_merged_v5.dtypes
# Out:
# city_resolvedAddress                            object
# day_datetime                                    object
# day_datetimeEpoch                                int64
# day_tempmax                                    float64
# day_tempmin                                    float64
# day_temp                                       float64
# day_dew                                        float64
# day_humidity                                   float64
# day_precip                                     float64
# day_precipcover                                float64
# day_solarradiation                             float64
# day_solarenergy                                float64
# day_uvindex                                    float64
# day_sunrise                                     object
# day_sunset                                      object
# day_moonphase                                  float64
# hour_datetime                                   object
# ...

# %%
df_merged_v5['day_datetime'] = pd.to_datetime(df_merged_v5['day_datetime'])

# %%
df_merged_v5['is_weekend'] = df_merged_v5.apply(lambda row: row['day_datetime'].day_name() in ['Saturday', 'Sunday'], axis=1)

# %%
df_merged_v5.head(100)
# Out:
#              city_resolvedAddress day_datetime  day_datetimeEpoch
# 0   Луцьк, Луцький район, Україна   2022-02-24         1645653600  \
# 1   Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 2   Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 3   Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 4   Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 5   Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 6   Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 7   Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 8   Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 9   Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 10  Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 11  Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 12  Луцьк, Луцький район, Україна   2022-02-24         1645653600
# ...

# %% [markdown]
# # Merging the final dataset with ISW data

# %%
ISW_DATA = 'data/4_final_dataset/isw_final.csv'
df_isw = pd.read_csv(ISW_DATA)
df_isw.head(10)
# Out:
#   report_date                                              title
# 0  2022-02-24  Russia-Ukraine Warning Update: Initial Russian...  \
# 1  2022-02-25  Russia-Ukraine Warning Update: Russian Offensi...
# 2  2022-02-26  Russia-Ukraine Warning Update: Russian Offensi...
# 3  2022-02-27  Russia-Ukraine Warning Update: Russian Offensi...
# 4  2022-02-28  Russian Offensive Campaign Assessment, Februar...
# 5  2022-03-01  Russian Offensive Campaign Assessment, March 1...
# 6  2022-03-02  Russian Offensive Campaign Assessment, March 2...
# 7  2022-03-03  Ukraine Conflict Update 14 | Institute for the...
# 8  2022-03-04  Ukraine Conflict Update 15 | Institute for the...
# 9  2022-03-05  Explainer on Russian Conscription, Reserve, an...
#
#                                           text_title
# 0  Russia-Ukraine Warning Update: Initial Russian...  \
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# ...

# %%
df_isw = df_isw.drop(columns={'title', 'text_title', 'main_text', 'text_stemm', 'report_date'})

# %%
df_isw.head(10)
# Out:
#                                            text_lemm
# 0   russian president vladimir putin began large ...  \
# 1   mason clark george barros kateryna stepanenko...
# 2   mason clark george barros katya stepanenko ru...
# 3   february twenty seven 4pm est russian militar...
# 4   russian military reorganizing military effort...
# 5   russian force completing reinforcement resupp...
# 6   russian force resumed offensive operation sup...
# 7   critical threat project aei march two thousan...
# 8   critical threat project aei march two thousan...
# 9   march two thousand and twenty two early annou...
#
#                                             keywords following_date
# 0  {'pm': 0.294, 'airport': 0.27, 'kyiv': 0.247, ...     2022-02-25
# 1  {'february': 0.341, 'kyiv': 0.326, 'pm': 0.263...     2022-02-26
# 2  {'february': 0.41, 'kyiv': 0.37, 'twenty': 0.2...     2022-02-27
# 3  {'february': 0.51, 'seven': 0.322, 'twenty': 0...     2022-02-28
# ...

# %%
df_isw['following_date'] = pd.to_datetime(df_isw['following_date'])

# %%
final_merged_dataset = pd.merge(df_merged_v5, df_isw, 
                                how='left', 
                                left_on='day_datetime', 
                                right_on='following_date')

# %%
final_merged_dataset.head(100)
# Out:
#              city_resolvedAddress day_datetime  day_datetimeEpoch
# 0   Луцьк, Луцький район, Україна   2022-02-24         1645653600  \
# 1   Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 2   Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 3   Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 4   Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 5   Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 6   Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 7   Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 8   Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 9   Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 10  Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 11  Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 12  Луцьк, Луцький район, Україна   2022-02-24         1645653600
# ...

# %%
exclude = {
    'following_date',
    'event_start',
    'event_end',
}

# %%
final_merged_dataset = final_merged_dataset.drop(columns=exclude)

# %%
final_merged_dataset.tail(100)
# Out:
#        city_resolvedAddress day_datetime  day_datetimeEpoch  day_tempmax
# 213099     Вінниця, Україна   2023-01-16         1673820000          3.7  \
# 213100     Вінниця, Україна   2023-01-16         1673820000          3.7
# 213101     Вінниця, Україна   2023-01-16         1673820000          3.7
# 213102     Вінниця, Україна   2023-01-16         1673820000          3.7
# 213103     Вінниця, Україна   2023-01-17         1673906400          7.1
# 213104     Вінниця, Україна   2023-01-17         1673906400          7.1
# 213105     Вінниця, Україна   2023-01-17         1673906400          7.1
# 213106     Вінниця, Україна   2023-01-17         1673906400          7.1
# 213107     Вінниця, Україна   2023-01-17         1673906400          7.1
# 213108     Вінниця, Україна   2023-01-17         1673906400          7.1
# 213109     Вінниця, Україна   2023-01-17         1673906400          7.1
# 213110     Вінниця, Україна   2023-01-17         1673906400          7.1
# ...

# %%
final_merged_dataset.to_csv(OUTPUT_DATA)
